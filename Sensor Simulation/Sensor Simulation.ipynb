# %% [markdown]
# ## Position Calculations
#
# ![image.png](attachment:image.png)

# %%
# Type of encoding
X1 = 1
X2 = 2
X4 = 4
# PPR
N = 2500
# Edge Count
EdgeCount = 2

AngleRotate = (EdgeCount/(X1*N))*360
print(AngleRotate, "Degree")
# Out:
# 0.28800000000000003 Degree

# %% [markdown]
# ## Between each pulse how much degree is travaled

# %%
import numpy as np
# Degree rotation per pulse
PPR = 1000
print(1/PPR, "Revolution per pulse")
Deg_per_pulse = 360/PPR
print("Degree rotation per pulse is", Deg_per_pulse, 'degree per pulse')
# Radian_per_pulse = (np.pi/180)*Deg_per_pulse
Radian_per_pulse = Deg_per_pulse*0.0174533
print("Radian per pulse is", Radian_per_pulse, 'radian per pulse')
# Out:
# 0.001 Revolution per pulse
# Degree rotation per pulse is 0.36 degree per pulse
# Radian per pulse is 0.006283188 radian per pulse

# %% [markdown]
# ## Convert RPM into radian per sec

# %%
RPM = 1000
angular_velocity = 2*np.pi*RPM*60
print('Angular Velocity', angular_velocity, 'Radian per sec')
Radian_per_sec = 0.1047*RPM
print('Convert RPM to radian per sec', Radian_per_sec, 'rad/sec')
Radian_chnage = Radian_per_sec*(1/3500)
print(Radian_chnage)
1/3500
# Out:
# Angular Velocity 376991.1184307751 Radian per sec
# Convert RPM to radian per sec 104.7 rad/sec
# 0.029914285714285716
# 0.00028571428571428574

# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(0, 10, 50, endpoint=False)
# Speed = np.sin(2 * np.pi * t) + 100 # In RPM
m = 45
c = 1000
Speed = m*t+c
plt.figure()
plt.plot(t, Speed)

# %% [markdown]
# ## Angular Displacemet

# %%
import time

t1 = time.time()
RPM = = m*t1+c
time.sleep(0.1)
t0 = time.time()
dt = t1-t0
Angular_Displacemet = angular_velocity*dt
# Out:
#   File "<ipython-input-1-b012fb2ca8d1>", line 4
#     RPM = = m*t1+c
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Torque Sensor Simulator
# - Calculate Bridge output from Torque change

# %%
T = 100 # Nm
