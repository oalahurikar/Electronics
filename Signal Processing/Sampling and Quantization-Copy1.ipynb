# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.signal import chirp
# %matplotlib notebook

# %% [markdown]
# # Analog Signal Defination

# %%
def signalsGen(Fs,Fc,StopTime,Amp):
    global t
    sampling_period = 1/Fs                   # seconds per sample
    sample_number  = StopTime / sampling_period; # Sample Number
    t = np.linspace(0, StopTime, sample_number) 
    Chirp = chirp(t, f0=2.5, f1=12.5, t1=StopTime, method='linear')*Amp+Amp
    ex = np.exp(-t*0.5)*Amp+Amp
    S = (np.sin(Fc*t))*Amp+Amp
    S_sq = (np.sin(Fc*t**2))*Amp+Amp
    C = (np.cos(Fc*t))*Amp+Amp
    Sq = signal.square(Fc * t)*Amp+Amp
    Saw = signal.sawtooth(Fc * t)*Amp+Amp
    return (Chirp, ex,S, S_sq,C,Sq,Saw)

# %%
Sig = signalsGen(Fs = 1000, StopTime= 10, Amp = 5, Fc=15)
# Out:
# C:\Users\olahurikar\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   """

# %% [markdown]
# # Signal Sampling

# %%
sampling_rate       = 100; # Hz
sampling_period     = 1. / sampling_rate; # s
print('sampling_period', sampling_period)
sample_number       = time / sampling_period;
print('sample_number', sample_number)
sampling_time       = np.linspace (0, time, sample_number);
Sampling_sig = analog_signal(sampling_time)
plt.close('all')
fig = plt.figure (figsize=(12,8), dpi=80)
plt.plot(analog_time, Analog_sig)
plt.plot(sampling_time, Sampling_sig)
plt.grid(True)
# Out:
# sampling_period 0.01
# sample_number 100.0
# C:\Users\olahurikar\AppData\Local\Continuum\Anaconda3\envs\fusion\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# <img src="data:image/png;base64,..." width="960">

# %% [markdown]
# # Quantization

# %%
# print('sampling_time', sampling_time)
# Quantization
quantizing_bits     = 10; # No of bits used to represent Analog Signal
quantizing_levels   = 2 ** quantizing_bits / 2; # 
print('quantizing_levels', quantizing_levels)
quantizing_step     = 1. / quantizing_levels;
print('quantizing_step', quantizing_step)
quantizing_signal   = np.round (Sampling_sig / quantizing_step) * quantizing_step;
plt.close('all')
fig = plt.figure (figsize=(12,8), dpi=80)
# quantizing_step = np.round((max(Analog_sig)-min(Analog_sig))/quantizing_levels)
plt.stem (sampling_time, quantizing_signal, linefmt='r-', markerfmt='rs', basefmt='r-');
plt.plot(sampling_time, Sampling_sig)
plt.grid(True)
# Out:
# quantizing_levels 512.0
# quantizing_step 0.001953125
# <img src="data:image/png;base64,..." width="960">

# %% [markdown]
# # Quantization using Scipy

# %%
from scipy import signal
f = signal.resample(Sampling_sig, sampling_rate)

fig = plt.figure (figsize=(12,8), dpi=80)
plt.plot (analog_time,   analog_signal (analog_time) );
#plt.stem (sampling_time, sampling_signal);
plt.stem (sampling_time, f, linefmt='r-', markerfmt='rs', basefmt='r-');
plt.title("Analog to digital signal conversion")
plt.xlabel("Time")
plt.ylabel("Amplitude")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="910.5263272150734">
